# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key

# %%
from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content


messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# To swap the keys and values in a dictionary using a functional programming approach, you can create a function that maps over the items of the dictionary and constructs a new dictionary with the keys and values swapped. Here’s a simple implementation in Python:
#
# ```python
# def swap_keys_values(input_dict):
#     # Check for duplicates in values before swapping, as they will become keys in the new dictionary
#     if len(set(input_dict.values())) != len(input_dict.values()):
#         raise ValueError("Duplicate values found. Cannot swap keys and values uniquely.")
#
#     # Use dictionary comprehension to swap keys and values
#     return {value: key for key, value in input_dict.items()}
#
# # Example usage:
# original_dict = {'a': 1, 'b': 2, 'c': 3}
# swapped_dict = swap_keys_values(original_dict)
# print(swapped_dict)  # Output: {1: 'a', 2: 'b', 3: 'c'}
# ```
#
# ### Considerations:
# 1. **Uniqueness of Values**: Before swapping, ensure that all values in the original dictionary are unique. This is because they will become keys in the swapped dictionary, and keys need to be unique.
# 2. **Functional Paradigm**: This solution uses dictionary comprehension, which is a concise and declarative approach, aligning with functional programming principles.
# 3. **Error Handling**: The function raises a `ValueError` if there are duplicate values, ensuring that the swap can occur uniquely.
#
# This approach is both efficient and aligns with functional programming practices by focusing on expressions and immutability.
